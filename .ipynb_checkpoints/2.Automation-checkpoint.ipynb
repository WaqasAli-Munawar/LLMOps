# %% [markdown]
# - You will use [Kubeflow Pipelines](https://www.kubeflow.org/docs/components/pipelines/v2/) to orchestrat and automate a workflow.
# - Kubeflow Pipelines is an open source framework. It's like a construction kit for building machine learning pipelines, making it easy to orchestrate and automate complex tasks.

# %%
from kfp import dsl
from kfp import compiler

# Ignore FutureWarnings in kfp
import warnings
warnings.filterwarnings("ignore", 
                        category=FutureWarning, 
                        module='kfp.*')

# %% [markdown]
# ## Kubeflow Pipelines
#
# - Kubeflow pipelines consist of two key concepts: Components and pipelines.
# - Pipeline components are like self-contained sets of code that perform various steps in your ML workflow, such as, the first step could be preprocessing data, and second step could betraining a model.
#
# ### Simple Pipeline Example
#
# ##### Build the pipeline

# %%
### Simple example: component 1
@dsl.component
def say_hello(name: str) -> str:
    hello_text = f'Hello, {name}!'
    
    return hello_text

# %% [markdown]
# - Since we "wrapped" this `say_hello` function in the decorator `@dsl.component`, the function will not actually return a string.
# - The function will return a `PipelineTask` object.

# %%
hello_task = say_hello(name="Erwin")
print(hello_task)
# Out:
# <kfp.dsl.pipeline_task.PipelineTask object at 0x7f4cfee51240>

# %% [markdown]
# - The object that we'll use to pass the information in `hello_text` to other components in the pipeline is `PipelineTask.output`, which will be a built-in data type:
# > `['String', 'Integer', 'Float', 'Boolean', 'List', 'Dict']`

# %%
print(hello_task.output)
# Out:
# {{channel:task=say-hello;name=Output;type=String;}}

# %% [markdown]
# - Note when passing in values to the a `dsl.component` function, you have to specify the argument names (keyword arguments), and can't use positional arguments.

# %%
# this will give an error and ask you to specify the parameter name
hello_task = say_hello("Erwin")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # this will give an error and ask you to specify the parameter name
# ----> 2 hello_task = say_hello("Erwin")
#
# File /usr/local/lib/python3.10/site-packages/kfp/dsl/base_component.py:75, in BaseComponent.__call__(self, *args, **kwargs)
#      72 task_inputs = {}
#      74 if args:
# ---> 75     raise TypeError(
#      76         'Components must be instantiated using keyword arguments. Positional '
#      77         f'parameters are not allowed (found {len(args)} such parameters for '
#      78         f'component "{self.name}").')
#      80 for k, v in kwargs.items():
#      81     if k not in self._component_inputs:
#
# TypeError: Components must be instantiated using keyword arguments. Positional parameters are not allowed (found 1 such parameters for component "say-hello").

# %% [markdown]
# - The second component is dependent on the first component
# - Take the output of the first component and pass it to the second component.

# %%
### Simple example: component 2
@dsl.component
def how_are_you(hello_text: str) -> str:
    
    how_are_you = f"{hello_text}. How are you?"
    
    return how_are_you

# %% [markdown]
# - Notice that when we pass in the return value from the `say_hello` function, we want to pass in the PipelineTask.output object, and not the PipelineTask object itself.

# %%
how_task = how_are_you(hello_text=hello_task.output)
print(how_task)
print(how_task.output)
# Out:
# <kfp.dsl.pipeline_task.PipelineTask object at 0x7f4cfe01e7a0>
# {{channel:task=how-are-you;name=Output;type=String;}}

# %%
# This will give an error and ask you to pass in a built-in data type
how_task = how_are_you(hello_text=hello_task)
print(how_task)
print(how_task.output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # This will give an error and ask you to pass in a built-in data type
# ----> 2 how_task = how_are_you(hello_text=hello_task)
#       3 print(how_task)
#       4 print(how_task.output)
#
# File /usr/local/lib/python3.10/site-packages/kfp/dsl/base_component.py:100, in BaseComponent.__call__(self, *args, **kwargs)
#      93     arguments = ', '.join(
#      94         arg_name.replace('-', '_') for arg_name in missing_arguments)
#      96     raise TypeError(
#      97         f'{self.name}() missing {len(missing_arguments)} required '
#      98         f'{argument_or_arguments}: {arguments}.')
# --> 100 return pipeline_task.PipelineTask(
#     101     component_spec=self.component_spec,
#     102     args=task_inputs,
#     103 )
#
# File /usr/local/lib/python3.10/site-packages/kfp/dsl/pipeline_task.py:86, in PipelineTask.__init__(self, component_spec, args)
#      80         raise ValueError(
#      81             f'Component {component_spec.name!r} got an unexpected input:'
#      82             f' {input_name!r}.')
#      84     input_spec = component_spec.inputs[input_name]
# ---> 86     type_utils.verify_type_compatibility(
#      87         given_value=argument_value,
#      88         expected_spec=input_spec,
#      89         error_message_prefix=(
#      90             f'Incompatible argument passed to the input '
#      91             f'{input_name!r} of component {component_spec.name!r}: '),
#      92     )
#      94 self.component_spec = component_spec
#      96 self._task_spec = structures.TaskSpec(
#      97     name=self._register_task_handler(),
#      98     inputs=dict(args.items()),
#      99     dependent_tasks=[],
#     100     component_ref=component_spec.name,
#     101     enable_caching=True)
#
# File /usr/local/lib/python3.10/site-packages/kfp/dsl/types/type_utils.py:260, in verify_type_compatibility(given_value, expected_spec, error_message_prefix, checks_input, raise_on_error)
#     258 # extract and normalize types
#     259 expected_type = expected_spec.type
# --> 260 given_type = _get_type_string_from_component_argument(given_value)
#     262 given_is_param = is_parameter_type(str(given_type))
#     263 if given_is_param:
#
# File /usr/local/lib/python3.10/site-packages/kfp/dsl/types/type_utils.py:230, in _get_type_string_from_component_argument(argument_value)
#     227 if argument_type in _TYPE_TO_TYPE_NAME:
#     228     return _TYPE_TO_TYPE_NAME[argument_type]
# --> 230 raise ValueError(
#     231     f'Constant argument inputs must be one of type {list(_TYPE_TO_TYPE_NAME.values())} Got: {argument_value!r} of type {type(argument_value)!r}.'
#     232 )
#
# ValueError: Constant argument inputs must be one of type ['String', 'Integer', 'Float', 'Boolean', 'List', 'Dict'] Got: <kfp.dsl.pipeline_task.PipelineTask object at 0x7f4cfee51240> of type <class 'kfp.dsl.pipeline_task.PipelineTask'>.

# %% [markdown]
# - Define the pipeline.
# - Notice how the input to `say_hello` is just `recipient`, since that is already a built-in data type (a String).
# - Recall that to get the value from a PipelineTask object, you'll use `PipelineTask.output` to pass in that value to another Pipeline Component function.
# - Notice that Pipeline function should return the PipelineTask.output as well.

# %%
### Simple example: pipeline
@dsl.pipeline
def hello_pipeline(recipient: str) -> str:
    
    # notice, just recipient and not recipient.output
    hello_task = say_hello(name=recipient)
    
    # notice .output
    how_task = how_are_you(hello_text=hello_task.output)
    
    # notice .output
    return how_task.output

# %% [markdown]
# - If you run this pipeline function, you'll see that the return value (`task.output` was a String) is again wrapped inside a PipelineTask object.

# %%
pipeline_output = hello_pipeline(recipient="Erwin")
print(pipeline_output)
# Out:
# <kfp.dsl.pipeline_task.PipelineTask object at 0x7f4cfdc67b80>

# %% [markdown]
# - Note that if you tried to return a PipelineTask object instead of the PipelineTask.output, you'd get an error message

# %%
### Pipeline with wrong return value type
@dsl.pipeline
def hello_pipeline_with_error(recipient: str) -> str:
    hello_task = say_hello(name=recipient)
    how_task = how_are_you(hello_text=hello_task.output)

    return how_task 
    # returning the PipelineTask object itself will give you an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 ### Pipeline with wrong return value type
#       2 @dsl.pipeline
# ----> 3 def hello_pipeline_with_error(recipient: str) -> str:
#       4     hello_task = say_hello(name=recipient)
#       5     how_task = how_are_you(hello_text=hello_task.output)
#
# File /usr/local/lib/python3.10/site-packages/kfp/dsl/pipeline_context.py:65, in pipeline(func, name, description, pipeline_root, display_name)
#      62 if pipeline_root:
#      63     func.pipeline_root = pipeline_root
# ---> 65 return component_factory.create_graph_component_from_func(
#      66     func,
#      67     name=name,
#      68     description=description,
#      69     display_name=display_name,
#      70 )
#
# File /usr/local/lib/python3.10/site-packages/kfp/dsl/component_factory.py:669, in create_graph_component_from_func(func, name, description, display_name)
#     658 """Implementation for the @pipeline decorator.
#     659
#     660 The decorator is defined under pipeline_context.py. See the
#     661 decorator for the canonical documentation for this function.
#     662 """
#     664 component_spec = extract_component_interface(
#     665     func,
#     666     description=description,
#     667     name=name,
#     668 )
# --> 669 return graph_component.GraphComponent(
#     670     component_spec=component_spec,
#     671     pipeline_func=func,
#     672     display_name=display_name,
#     673 )
#
# File /usr/local/lib/python3.10/site-packages/kfp/dsl/graph_component.py:68, in GraphComponent.__init__(self, component_spec, pipeline_func, display_name)
#      65 pipeline_group = dsl_pipeline.groups[0]
#      66 pipeline_group.name = uuid.uuid4().hex
# ---> 68 pipeline_spec, platform_spec = builder.create_pipeline_spec(
#      69     pipeline=dsl_pipeline,
#      70     component_spec=self.component_spec,
#      71     pipeline_outputs=pipeline_outputs,
#      72 )
#      74 pipeline_root = getattr(pipeline_func, 'pipeline_root', None)
#      75 if pipeline_root is not None:
#
# File /usr/local/lib/python3.10/site-packages/kfp/compiler/pipeline_spec_builder.py:1838, in create_pipeline_spec(pipeline, component_spec, pipeline_outputs)
#    1832 pipeline_spec.root.CopyFrom(
#    1833     _build_component_spec_from_component_spec_structure(component_spec))
#    1835 # TODO: add validation of returned outputs -- it's possible to return
#    1836 # an output from a task in a condition group, for example, which isn't
#    1837 # caught until submission time using Vertex SDK client
# -> 1838 pipeline_outputs_dict = convert_pipeline_outputs_to_dict(pipeline_outputs)
#    1839 validate_pipeline_outputs_dict(pipeline_outputs_dict)
#    1841 root_group = pipeline.groups[0]
#
# File /usr/local/lib/python3.10/site-packages/kfp/compiler/pipeline_spec_builder.py:1941, in convert_pipeline_outputs_to_dict(pipeline_outputs)
#    1939     return dict(pipeline_outputs._asdict())
#    1940 else:
# -> 1941     raise ValueError(f'Got unknown pipeline output: {pipeline_outputs}')
#
# ValueError: Got unknown pipeline output: <kfp.dsl.pipeline_task.PipelineTask object at 0x7f4cfe041ab0>

# %% [markdown]
# ##### Implement the pipeline
#
# - A pipeline is a set of components that you orchestrate.
# - It lets you define the order of execution and how data flows from one step to another.
# - Compile the pipeline into a yaml file, `pipeline.yaml`
# - You can look at the `pipeline.yaml` file in your workspace by going to `File --> Open...`. Or right here in the notebook (two cells below)

# %%
compiler.Compiler().compile(hello_pipeline, 'pipeline.yaml')

# %% [markdown]
# - Define the arguments, the input that goes into the pipeline.

# %%
pipeline_arguments = {
    "recipient": "World!",
}

# %% [markdown]
# - View the `pipeline.yaml`

# %%
# !cat pipeline.yaml
# Out:
# # PIPELINE DEFINITION
# # Name: hello-pipeline
# # Inputs:
# #    recipient: str
# # Outputs:
# #    Output: str
# components:
#   comp-how-are-you:
#     executorLabel: exec-how-are-you
#     inputDefinitions:
#       parameters:
#         hello_text:
#           parameterType: STRING
#     outputDefinitions:
#       parameters:
#         Output:
#           parameterType: STRING
#   comp-say-hello:
#     executorLabel: exec-say-hello
#     inputDefinitions:
#       parameters:
#         name:
#           parameterType: STRING
#     outputDefinitions:
#       parameters:
#         Output:
#           parameterType: STRING
# deploymentSpec:
#   executors:
#     exec-how-are-you:
#       container:
#         args:
#         - --executor_input
#         - '{{$}}'
#         - --function_to_execute
#         - how_are_you
#         command:
#         - sh
#         - -c
#         - "\nif ! [ -x \"$(command -v pip)\" ]; then\n    python3 -m ensurepip ||\
#           \ python3 -m ensurepip --user || apt-get install python3-pip\nfi\n\nPIP_DISABLE_PIP_VERSION_CHECK=1\
#           \ python3 -m pip install --quiet --no-warn-script-location 'kfp==2.4.0'\
#           \ '--no-deps' 'typing-extensions>=3.7.4,<5; python_version<\"3.9\"' && \"\
#           $0\" \"$@\"\n"
#         - sh
#         - -ec
#         - 'program_path=$(mktemp -d)
#
#
#           printf "%s" "$0" > "$program_path/ephemeral_component.py"
#
#           _KFP_RUNTIME=true python3 -m kfp.dsl.executor_main                         --component_module_path                         "$program_path/ephemeral_component.py"                         "$@"
#
#           '
#         - "\nimport kfp\nfrom kfp import dsl\nfrom kfp.dsl import *\nfrom typing import\
#           \ *\n\ndef how_are_you(hello_text: str) -> str:\n\n    how_are_you = f\"\
#           {hello_text}. How are you?\"\n\n    return how_are_you\n\n"
#         image: python:3.7
#     exec-say-hello:
#       container:
#         args:
#         - --executor_input
#         - '{{$}}'
#         - --function_to_execute
#         - say_hello
#         command:
#         - sh
#         - -c
#         - "\nif ! [ -x \"$(command -v pip)\" ]; then\n    python3 -m ensurepip ||\
#           \ python3 -m ensurepip --user || apt-get install python3-pip\nfi\n\nPIP_DISABLE_PIP_VERSION_CHECK=1\
#           \ python3 -m pip install --quiet --no-warn-script-location 'kfp==2.4.0'\
#           \ '--no-deps' 'typing-extensions>=3.7.4,<5; python_version<\"3.9\"' && \"\
#           $0\" \"$@\"\n"
#         - sh
#         - -ec
#         - 'program_path=$(mktemp -d)
#
#
#           printf "%s" "$0" > "$program_path/ephemeral_component.py"
#
#           _KFP_RUNTIME=true python3 -m kfp.dsl.executor_main                         --component_module_path                         "$program_path/ephemeral_component.py"                         "$@"
#
#           '
#         - "\nimport kfp\nfrom kfp import dsl\nfrom kfp.dsl import *\nfrom typing import\
#           \ *\n\ndef say_hello(name: str) -> str:\n    hello_text = f'Hello, {name}!'\n\
#           \n    return hello_text\n\n"
#         image: python:3.7
# pipelineInfo:
#   name: hello-pipeline
# root:
#   dag:
#     outputs:
#       parameters:
#         Output:
#           valueFromParameter:
#             outputParameterKey: Output
#             producerSubtask: how-are-you
#     tasks:
#       how-are-you:
#         cachingOptions:
#           enableCache: true
#         componentRef:
#           name: comp-how-are-you
#         dependentTasks:
#         - say-hello
#         inputs:
#           parameters:
#             hello_text:
#               taskOutputParameter:
#                 outputParameterKey: Output
#                 producerTask: say-hello
#         taskInfo:
#           name: how-are-you
#       say-hello:
#         cachingOptions:
#           enableCache: true
#         componentRef:
#           name: comp-say-hello
#         inputs:
#           parameters:
#             name:
#               componentInputParameter: recipient
#         taskInfo:
#           name: say-hello
#   inputDefinitions:
#     parameters:
#       recipient:
#         parameterType: STRING
#   outputDefinitions:
#     parameters:
#       Output:
#         parameterType: STRING
# schemaVersion: 2.1.0
# sdkVersion: kfp-2.4.0

# %% [markdown]
# - You can use [Vertex AI pipelines](https://cloud.google.com/vertex-ai/docs/pipelines/introduction), a *managed*, serverless environment, to execute the yaml files.
#
# **Note**: Due to classroom restrictions, the execution will not take place in this notebook. But, if you were to execute it in your own environment, the code is provided below (for the simple example from above):

# %% [markdown]
# ```python
# ### import `PipelineJob`
# from google.cloud.aiplatform import PipelineJob
#
# job = PipelineJob(
#         ### path of the yaml file to execute
#         template_path="pipeline.yaml",
#         ### name of the pipeline
#         display_name=f"deep_learning_ai_pipeline",
#         ### pipeline arguments (inputs)
#         ### {"recipient": "World!"} for this example
#         parameter_values=pipeline_arguments,
#         ### region of execution
#         location="us-central1",
#         ### root is where temporary files are being
#         ### stored by the execution engine
#         pipeline_root="./",
# )
#
# ### submit for execution
# job.submit()
#
# ### check to see the status of the job
# job.state
# ```

# %% [markdown]
# - This is how the "hello world pipeline" would look like:
#
# For **say_hello**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# For **how_are_you**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Real-life Pipeline Example
#
# #### Automation and Orchestration of a Supervised Tuning Pipeline.
#
# - Reuse an existing Kubeflow Pipeline for Parameter-Efficient Fine-Tuning (PEFT) for a foundation model from Google, called [PaLM 2](https://ai.google/discover/palm2/).
# - Advantage of reusing a pipleline means you do not have to build it from scratch, you can only specify some of the parameters.

# %%
### these are the same 
### jsonl files from the previous lab

### time stamps have been removed so that 
### the files are consistent for all learners
TRAINING_DATA_URI = "./tune_data_stack_overflow_python_qa.jsonl" 
EVAUATION_DATA_URI = "./tune_eval_data_stack_overflow_python_qa.jsonl"

# %% [markdown]
# - Provide the model with a version.
# - Versioning model allows for:
#   - Reproducibility: Reproduce your results and ensure your models perform as expected.
#   - Auditing: Track changes to your models.
#   - Rollbacks: Roll back to a previous version of your model.

# %%
### path to the pipeline file to reuse
### the file is provided in your workspace as well
template_path = 'https://us-kfp.pkg.dev/ml-pipeline/\
large-language-model-pipelines/tune-large-model/v2.0.0'

# %%
import datetime

# %%
date = datetime.datetime.now().strftime("%H:%d:%m:%Y")

# %%
MODEL_NAME = f"deep-learning-ai-model-{date}"

# %% [markdown]
# - This example uses two PaLM model parameters:
#   - `TRAINING_STEPS`: Number of training steps to use when tuning the model. For extractive QA you can set it from 100-500.
#   - `EVALUATION_INTERVAL`: The interval determines how frequently a trained model is evaluated against the created *evaluation set* to assess its performance and identify issues. Default will be 20, which means after every 20 training steps, the model is evaluated on the evaluation dataset.

# %%
TRAINING_STEPS = 200
EVALUATION_INTERVAL = 20

# %% [markdown]
# - Load the Project ID and credentials

# %%
from utils import authenticate
credentials, PROJECT_ID = authenticate()

# %%
REGION = "us-central1"

# %% [markdown]
# - Define the arguments, the input that goes into the pipeline.

# %%
pipeline_arguments = {
    "model_display_name": MODEL_NAME,
    "location": REGION,
    "large_model_reference": "text-bison@001",
    "project": PROJECT_ID,
    "train_steps": TRAINING_STEPS,
    "dataset_uri": TRAINING_DATA_URI,
    "evaluation_interval": EVALUATION_INTERVAL,
    "evaluation_data_uri": EVAUATION_DATA_URI,
}

# %% [markdown]
# **Note**: Due to classroom restrictions, the execution will not take place in this notebook. But, if you were to execute it in your own environment, the code is provided below (for the real-life example from above). Keep in mind, **running this execution is time consuming and expensive**:

# %% [markdown]
# ```Python
# pipeline_root "./"
#
# job = PipelineJob(
#         ### path of the yaml file to execute
#         template_path=template_path,
#         ### name of the pipeline
#         display_name=f"deep_learning_ai_pipeline-{date}",
#         ### pipeline arguments (inputs)
#         parameter_values=pipeline_arguments,
#         ### region of execution
#         location=REGION,
#         ### root is where temporary files are being
#         ### stored by the execution engine
#         pipeline_root=pipeline_root,
#         ### enable_caching=True will save the outputs
#         ### of components for re-use, and will only re-run those
#         ### components for which the code or data has changed.
#         enable_caching=True,
# )
#
# ### submit for execution
# job.submit()
#
# ### check to see the status of the job
# job.state
# ```

# %% [markdown]
# - This is how the successful execution of the job would display like:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - This is how the pipeline graph would look like:
#
# ![image.png](attachment:image.png)
